# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## WTI

# %%
df = pd.read_excel("Stationary Data/WTI.xlsx") 
df
# Out:
#           DATE  MCOILWTICO  MCOILWTICO_LAG  EMVOVERALLEMV  EUEPUINDXM  \
# 0   2001-10-01   -0.167019       -0.043688          22.46      141.35
# 1   2001-11-01   -0.121172       -0.167019         -13.09      -10.39
# 2   2001-12-01   -0.012811       -0.121172          -2.94      -39.39
# 3   2002-01-01    0.016876       -0.012811          -2.04      -53.76
# 4   2002-02-01    0.049466        0.016876           4.29       -5.87
# ..         ...         ...             ...            ...         ...
# 260 2023-06-01   -0.018755       -0.104312           2.93       21.28
# 261 2023-07-01    0.079594       -0.018755          -5.14      -18.30
# 262 2023-08-01    0.067598        0.079594          -0.72       16.36
# 263 2023-09-01    0.094204        0.067598          -0.83       24.39
# 264 2023-10-01   -0.043304        0.094204           2.30      -11.96
#
#      GACDISA066MSFRBNY  TB3MS  INFECTDISEMVTRACK  PNICKUSDM  COV19  RUWAR
# ...

# %%
df.rename(columns = {'MCOILWTICO':'WTI'}, inplace = True) 
df.rename(columns = {'MCOILWTICO_LAG':'WTI_LAG'}, inplace = True) 

df.rename(columns = {'EMVOVERALLEMV':'Equity Market Volatility'}, inplace = True) 
df.rename(columns = {'EUEPUINDXM':'Economic Policy Uncertainty Europe'}, inplace = True) 
df.rename(columns = {'GACDISA066MSFRBNY':'NY Business Conditions'}, inplace = True)
df.rename(columns = {'TB3MS':'3 Month Treasury Bill'}, inplace = True) 
df.rename(columns = {'INFECTDISEMVTRACK':'Infectious Disease Tracker'}, inplace = True) 
df.rename(columns = {'PNICKUSDM':'Nickel'}, inplace = True) 

df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)
df
# Out:
#                  WTI   WTI_LAG  Equity Market Volatility  \
# DATE
# 2001-10-01 -0.167019 -0.043688                     22.46
# 2001-11-01 -0.121172 -0.167019                    -13.09
# 2001-12-01 -0.012811 -0.121172                     -2.94
# 2002-01-01  0.016876 -0.012811                     -2.04
# 2002-02-01  0.049466  0.016876                      4.29
# ...              ...       ...                       ...
# 2023-06-01 -0.018755 -0.104312                      2.93
# 2023-07-01  0.079594 -0.018755                     -5.14
# 2023-08-01  0.067598  0.079594                     -0.72
# 2023-09-01  0.094204  0.067598                     -0.83
# 2023-10-01 -0.043304  0.094204                      2.30
#
#             Economic Policy Uncertainty Europe  NY Business Conditions  \
# DATE
# 2001-10-01                              141.35                    -4.5
# 2001-11-01                              -10.39                    -2.2
# ...

# %%
df.to_excel("Renamed Columns Stationary Data/WTI.xlsx", index=True)
print("DataFrame saved")
# Out:
# DataFrame saved

# %% [markdown]
# ## EUNG

# %%
df = pd.read_excel("Stationary Data/EUNG.xlsx") 
df
# Out:
#           DATE  PNGASEUUSDM  PNGASEUUSDM_LAG  EMVOVERALLEMV  EUEPUINDXM  \
# 0   2001-10-01    -0.154151         0.000000          22.46      141.35
# 1   2001-11-01     0.000000        -0.154151         -13.09      -10.39
# 2   2001-12-01    -0.006192         0.000000          -2.94      -39.39
# 3   2002-01-01    -0.143340        -0.006192          -2.04      -53.76
# 4   2002-02-01     0.000000        -0.143340           4.29       -5.87
# ..         ...          ...              ...            ...         ...
# 260 2023-06-01     0.031592        -0.316354           2.93       21.28
# 261 2023-07-01    -0.068368         0.031592          -5.14      -18.30
# 262 2023-08-01     0.109307        -0.068368          -0.72       16.36
# 263 2023-09-01     0.064130         0.109307          -0.83       24.39
# 264 2023-10-01     0.158267         0.064130           2.30      -11.96
#
#      GACDISA066MSFRBNY  TB3MS  INFECTDISEMVTRACK  PNICKUSDM  COV19  RUWAR
# ...

# %%
df.rename(columns = {'PNGASEUUSDM':'EUNG'}, inplace = True) 
df.rename(columns = {'PNGASEUUSDM_LAG':'EUNG_LAG'}, inplace = True) 

df.rename(columns = {'EMVOVERALLEMV':'Equity Market Volatility'}, inplace = True) 
df.rename(columns = {'EUEPUINDXM':'Economic Policy Uncertainty Europe'}, inplace = True) 
df.rename(columns = {'GACDISA066MSFRBNY':'NY Business Conditions'}, inplace = True)
df.rename(columns = {'TB3MS':'3 Month Treasury Bill'}, inplace = True) 
df.rename(columns = {'INFECTDISEMVTRACK':'Infectious Disease Tracker'}, inplace = True) 
df.rename(columns = {'PNICKUSDM':'Nickel'}, inplace = True) 

df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)
df
# Out:
#                 EUNG  EUNG_LAG  Equity Market Volatility  \
# DATE
# 2001-10-01 -0.154151  0.000000                     22.46
# 2001-11-01  0.000000 -0.154151                    -13.09
# 2001-12-01 -0.006192  0.000000                     -2.94
# 2002-01-01 -0.143340 -0.006192                     -2.04
# 2002-02-01  0.000000 -0.143340                      4.29
# ...              ...       ...                       ...
# 2023-06-01  0.031592 -0.316354                      2.93
# 2023-07-01 -0.068368  0.031592                     -5.14
# 2023-08-01  0.109307 -0.068368                     -0.72
# 2023-09-01  0.064130  0.109307                     -0.83
# 2023-10-01  0.158267  0.064130                      2.30
#
#             Economic Policy Uncertainty Europe  NY Business Conditions  \
# DATE
# 2001-10-01                              141.35                    -4.5
# 2001-11-01                              -10.39                    -2.2
# ...

# %%
df.to_excel("Renamed Columns Stationary Data/EUNG.xlsx", index=True)
print("DataFrame saved")
# Out:
# DataFrame saved

# %% [markdown]
# ## ASIALNG

# %%
df = pd.read_excel("Stationary Data/ASIALNG.xlsx") 
df
# Out:
#           DATE  PNGASJPUSDM  PNGASJPUSDM_LAG  EMVOVERALLEMV  EUEPUINDXM  \
# 0   2001-10-01     0.004310        -0.021368          22.46      141.35
# 1   2001-11-01    -0.163152         0.004310         -13.09      -10.39
# 2   2001-12-01    -0.070803        -0.163152          -2.94      -39.39
# 3   2002-01-01    -0.030347        -0.070803          -2.04      -53.76
# 4   2002-02-01     0.019418        -0.030347           4.29       -5.87
# ..         ...          ...              ...            ...         ...
# 260 2023-06-01     0.020990        -0.193205           2.93       21.28
# 261 2023-07-01     0.073401         0.020990          -5.14      -18.30
# 262 2023-08-01     0.076927         0.073401          -0.72       16.36
# 263 2023-09-01     0.112569         0.076927          -0.83       24.39
# 264 2023-10-01     0.150777         0.112569           2.30      -11.96
#
#      GACDISA066MSFRBNY  TB3MS  INFECTDISEMVTRACK  PNICKUSDM  COV19  RUWAR
# ...

# %%
df.rename(columns = {'PNGASJPUSDM':'ASIALNG'}, inplace = True) 
df.rename(columns = {'PNGASJPUSDM_LAG':'ASIALNG_LAG'}, inplace = True) 

df.rename(columns = {'EMVOVERALLEMV':'Equity Market Volatility'}, inplace = True) 
df.rename(columns = {'EUEPUINDXM':'Economic Policy Uncertainty Europe'}, inplace = True) 
df.rename(columns = {'GACDISA066MSFRBNY':'NY Business Conditions'}, inplace = True)
df.rename(columns = {'TB3MS':'3 Month Treasury Bill'}, inplace = True) 
df.rename(columns = {'INFECTDISEMVTRACK':'Infectious Disease Tracker'}, inplace = True) 
df.rename(columns = {'PNICKUSDM':'Nickel'}, inplace = True) 

df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)
df
# Out:
#              ASIALNG  ASIALNG_LAG  Equity Market Volatility  \
# DATE
# 2001-10-01  0.004310    -0.021368                     22.46
# 2001-11-01 -0.163152     0.004310                    -13.09
# 2001-12-01 -0.070803    -0.163152                     -2.94
# 2002-01-01 -0.030347    -0.070803                     -2.04
# 2002-02-01  0.019418    -0.030347                      4.29
# ...              ...          ...                       ...
# 2023-06-01  0.020990    -0.193205                      2.93
# 2023-07-01  0.073401     0.020990                     -5.14
# 2023-08-01  0.076927     0.073401                     -0.72
# 2023-09-01  0.112569     0.076927                     -0.83
# 2023-10-01  0.150777     0.112569                      2.30
#
#             Economic Policy Uncertainty Europe  NY Business Conditions  \
# DATE
# 2001-10-01                              141.35                    -4.5
# 2001-11-01                              -10.39                    -2.2
# ...

# %%
df.to_excel("Renamed Columns Stationary Data/ASIALNG.xlsx", index=True)
print("DataFrame saved")
# Out:
# DataFrame saved
