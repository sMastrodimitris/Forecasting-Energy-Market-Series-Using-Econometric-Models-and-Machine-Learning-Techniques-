# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
from pmdarima import auto_arima

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid", color_codes=True)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Functions

# %%
def plotFor(test,forecasts):
    # Plotting the true values and the predicted values
    plt.figure(figsize=(12, 4))
    plt.plot(test, label='True Values', marker='o')
    plt.plot(forecasts, label='Predicted Values', marker='x')
    plt.title('Regression Forecast for the Last 24 Observations')
    plt.xlabel('Time')
    plt.ylabel('WTI Price')
    plt.legend()
    plt.show()

def calculateMAE(test, forecasts):
    mae = mean_absolute_error(test, forecasts)
    return mae

def calculateMAPE(test, forecasts):
    percentage_errors = [abs((actual - predicted) / actual) * 100 for actual, predicted in zip(test, forecasts) if actual != 0]
    mape = sum(percentage_errors) / len(percentage_errors)
    return mape

def calculateMSE(test, forecasts):
    mse = mean_squared_error(test, forecasts)
    return mse

def calculateRMSE(test, forecasts):
    mse = mean_squared_error(test, forecasts)
    rmse = sqrt(mse)
    return rmse

# %% [markdown]
# ## Import Data

# %%
df = pd.read_excel("Renamed Columns Stationary Data/WTI.xlsx") 
df['DATE'] = pd.to_datetime(df['DATE'])
df.set_index('DATE', inplace=True)
df
# Out:
#                  WTI   WTI_LAG  Equity Market Volatility  \
# DATE
# 2001-10-01 -0.167019 -0.043688                     22.46
# 2001-11-01 -0.121172 -0.167019                    -13.09
# 2001-12-01 -0.012811 -0.121172                     -2.94
# 2002-01-01  0.016876 -0.012811                     -2.04
# 2002-02-01  0.049466  0.016876                      4.29
# ...              ...       ...                       ...
# 2023-06-01 -0.018755 -0.104312                      2.93
# 2023-07-01  0.079594 -0.018755                     -5.14
# 2023-08-01  0.067598  0.079594                     -0.72
# 2023-09-01  0.094204  0.067598                     -0.83
# 2023-10-01 -0.043304  0.094204                      2.30
#
#             Economic Policy Uncertainty Europe  NY Business Conditions  \
# DATE
# 2001-10-01                              141.35                    -4.5
# 2001-11-01                              -10.39                    -2.2
# 2001-12-01                              -39.39                    -6.8
# 2002-01-01                              -53.76                    11.7
# 2002-02-01                               -5.87                    11.2
# ...                                        ...                     ...
# 2023-06-01                               21.28                   -42.6
# 2023-07-01                              -18.30                    38.4
# 2023-08-01                               16.36                    -5.5
# 2023-09-01                               24.39                   -20.1
# 2023-10-01                              -11.96                    20.9
#
#             3 Month Treasury Bill  Infectious Disease Tracker    Nickel  \
# DATE
# 2001-10-01                  -0.72                        0.39 -0.088497
# 2001-11-01                  -0.48                       -0.06 -0.045894
# 2001-12-01                  -0.29                        0.09  0.060355
# 2002-01-01                  -0.18                       -0.39  0.035324
# 2002-02-01                  -0.04                        0.29  0.131247
# ...                           ...                         ...       ...
# 2023-06-01                   0.22                        2.32 -0.071308
# 2023-07-01                   0.02                       -2.45 -0.041580
# 2023-08-01                   0.09                       -0.81 -0.006711
# 2023-09-01                   0.05                       -0.58 -0.031054
# 2023-10-01                   0.02                       -0.26 -0.040000
#
#             COV19  RUWAR
# DATE
# 2001-10-01      0      0
# 2001-11-01      0      0
# 2001-12-01      0      0
# 2002-01-01      0      0
# 2002-02-01      0      0
# ...           ...    ...
# 2023-06-01      1      1
# 2023-07-01      1      1
# 2023-08-01      1      1
# 2023-09-01      1      1
# 2023-10-01      1      1
#
# [265 rows x 10 columns]

# %% [markdown]
# ## Test Importance

# %%
y = df['WTI']
X = df[["WTI_LAG","Equity Market Volatility","Economic Policy Uncertainty Europe","NY Business Conditions","3 Month Treasury Bill","Infectious Disease Tracker","Nickel","COV19","RUWAR"]]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
summary = model.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WTI   R-squared:                       0.211
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     7.575
# Date:                Sat, 20 Jan 2024   Prob (F-statistic):           7.77e-10
# Time:                        12:27:07   Log-Likelihood:                 250.96
# No. Observations:                 265   AIC:                            -481.9
# Df Residuals:                     255   BIC:                            -446.1
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.0031      0.006      0.481      0.631      -0.010       0.016
# WTI_LAG                                0.2026      0.062      3.282      0.001       0.081       0.324
# Equity Market Volatility              -0.0007      0.001     -0.803      0.422      -0.003       0.001
# Economic Policy Uncertainty Europe    -0.0002      0.000     -1.683      0.094      -0.001    4.02e-05
# NY Business Conditions                -0.0004      0.000     -0.763      0.446      -0.001       0.001
# 3 Month Treasury Bill                  0.0295      0.036      0.814      0.416      -0.042       0.101
# Infectious Disease Tracker            -0.0075      0.002     -4.283      0.000      -0.011      -0.004
# Nickel                                 0.0901      0.072      1.252      0.212      -0.052       0.232
# COV19                                  0.0130      0.020      0.640      0.523      -0.027       0.053
# RUWAR                                 -0.0269      0.030     -0.883      0.378      -0.087       0.033
# ==============================================================================
# Omnibus:                       21.744   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.679
# Skew:                          -0.201   Prob(JB):                     4.49e-16
# Kurtosis:                       5.498   Cond. No.                         575.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Prune Dataset

# %%
selected_columns = ["WTI","WTI_LAG","Economic Policy Uncertainty Europe","Infectious Disease Tracker"]
pruned_df = df[selected_columns]

pruned_df = pruned_df.set_index(df.index)
pruned_df
# Out:
#                  WTI   WTI_LAG  Economic Policy Uncertainty Europe  \
# DATE
# 2001-10-01 -0.167019 -0.043688                              141.35
# 2001-11-01 -0.121172 -0.167019                              -10.39
# 2001-12-01 -0.012811 -0.121172                              -39.39
# 2002-01-01  0.016876 -0.012811                              -53.76
# 2002-02-01  0.049466  0.016876                               -5.87
# ...              ...       ...                                 ...
# 2023-06-01 -0.018755 -0.104312                               21.28
# 2023-07-01  0.079594 -0.018755                              -18.30
# 2023-08-01  0.067598  0.079594                               16.36
# 2023-09-01  0.094204  0.067598                               24.39
# 2023-10-01 -0.043304  0.094204                              -11.96
#
#             Infectious Disease Tracker
# DATE
# 2001-10-01                        0.39
# 2001-11-01                       -0.06
# 2001-12-01                        0.09
# 2002-01-01                       -0.39
# 2002-02-01                        0.29
# ...                                ...
# 2023-06-01                        2.32
# 2023-07-01                       -2.45
# 2023-08-01                       -0.81
# 2023-09-01                       -0.58
# 2023-10-01                       -0.26
#
# [265 rows x 4 columns]

# %% [markdown]
# ## Simple Regressor

# %%
train = pruned_df[:-24]
test = pruned_df[-24:]

X_train = train[['WTI_LAG']]
y_train = train['WTI']

X_test = test[['WTI_LAG']]
y_test = test['WTI']

X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# Fit the regression model
model = sm.OLS(y_train, X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WTI   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     22.23
# Date:                Sat, 20 Jan 2024   Prob (F-statistic):           4.11e-06
# Time:                        12:27:10   Log-Likelihood:                 206.10
# No. Observations:                 241   AIC:                            -408.2
# Df Residuals:                     239   BIC:                            -401.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.007      0.532      0.596      -0.010       0.017
# WTI_LAG        0.2924      0.062      4.715      0.000       0.170       0.415
# ==============================================================================
# Omnibus:                       64.791   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1295.779
# Skew:                           0.399   Prob(JB):                    4.22e-282
# Kurtosis:                      14.332   Cond. No.                         9.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Make predictions
predictions = model.predict(X_test)

plotFor(y_test,predictions)

# %%
print(f"MAE: {calculateMAE(y_test, predictions):.4f}")
print(f"MAPE: {calculateMAPE(y_test, predictions):.4f} %")
print(f"MSE: {calculateMSE(y_test, predictions):.4f}")
print(f"RMSE: {calculateRMSE(y_test, predictions):.4f}")
# Out:
# MAE: 0.0772
# MAPE: 115.0591 %
# MSE: 0.0076
# RMSE: 0.0870

# %% [markdown]
# ### Save

# %%
df = pd.DataFrame({'WTI M UR': predictions, 'Actual': y_test})
df.to_excel("WTI_M_UR_forecast.xlsx", index=True)
df
# Out:
#             WTI M UR    Actual
# DATE
# 2021-11-01  0.041135 -0.029013
# 2021-12-01 -0.004944 -0.098715
# 2022-01-01 -0.025326  0.148857
# 2022-02-01  0.047069  0.096380
# 2022-03-01  0.031724  0.168882
# 2022-04-01  0.052925 -0.063937
# 2022-05-01 -0.015156  0.073567
# 2022-06-01  0.025053  0.047159
# 2022-07-01  0.017330 -0.122299
# 2022-08-01 -0.032223 -0.081462
# 2022-09-01 -0.020281 -0.105871
# 2022-10-01 -0.027419  0.038303
# 2022-11-01  0.014741 -0.036998
# 2022-12-01 -0.007279 -0.098706
# 2023-01-01 -0.025323  0.021740
# 2023-02-01  0.009897 -0.016651
# 2023-03-01 -0.001329 -0.047307
# 2023-04-01 -0.010293  0.080840
# 2023-05-01  0.027180 -0.104312
# 2023-06-01 -0.026963 -0.018755
# 2023-07-01 -0.001944  0.079594
# 2023-08-01  0.026815  0.067598
# 2023-09-01  0.023307  0.094204
# 2023-10-01  0.031087 -0.043304

# %%
# Open a file in write mode
with open('WTI M UR Results.txt', 'w') as file:
    # Write the variables to the file
    file.write(f'{calculateMAE(y_test, predictions):.4f}\n')
    file.write(f'{calculateMAPE(y_test, predictions):.4f}\n')
    file.write(f'{calculateMSE(y_test, predictions):.4f}\n')
    file.write(f'{calculateRMSE(y_test, predictions):.4f}\n')

# %% [markdown]
# ## Multiple Regressor

# %%
train = pruned_df[:-24]
test = pruned_df[-24:]

X_train = train[['WTI_LAG','Economic Policy Uncertainty Europe','Infectious Disease Tracker']]
y_train = train['WTI']

X_test = test[['WTI_LAG','Economic Policy Uncertainty Europe','Infectious Disease Tracker']]
y_test = test['WTI']

X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# Fit the regression model
model = sm.OLS(y_train, X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WTI   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     28.39
# Date:                Sat, 20 Jan 2024   Prob (F-statistic):           1.01e-15
# Time:                        12:27:19   Log-Likelihood:                 232.37
# No. Observations:                 241   AIC:                            -456.7
# Df Residuals:                     237   BIC:                            -442.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.0054      0.006      0.895      0.372      -0.006       0.017
# WTI_LAG                                0.2269      0.057      4.014      0.000       0.116       0.338
# Economic Policy Uncertainty Europe    -0.0003      0.000     -2.035      0.043      -0.001   -9.37e-06
# Infectious Disease Tracker            -0.0111      0.002     -6.764      0.000      -0.014      -0.008
# ==============================================================================
# Omnibus:                       19.560   Durbin-Watson:                   1.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.749
# Skew:                          -0.074   Prob(JB):                     1.18e-15
# Kurtosis:                       5.612   Cond. No.                         404.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Make predictions
predictions = model.predict(X_test)

plotFor(y_test,predictions)

# %%
print(f"MAE: {calculateMAE(y_test, predictions):.4f}")
print(f"MAPE: {calculateMAPE(y_test, predictions):.4f} %")
print(f"MSE: {calculateMSE(y_test, predictions):.4f}")
print(f"RMSE: {calculateRMSE(y_test, predictions):.4f}")
# Out:
# MAE: 0.0995
# MAPE: 166.1762 %
# MSE: 0.0146
# RMSE: 0.1208

# %% [markdown]
# ### Save

# %%
df = pd.DataFrame({'WTI M MR': predictions, 'Actual': y_test})
df.to_excel("WTI_M_MR_forecast.xlsx", index=True)
df
# Out:
#             WTI M MR    Actual
# DATE
# 2021-11-01  0.251562 -0.029013
# 2021-12-01  0.018668 -0.098715
# 2022-01-01 -0.056123  0.148857
# 2022-02-01  0.008231  0.096380
# 2022-03-01  0.072188  0.168882
# 2022-04-01  0.009825 -0.063937
# 2022-05-01  0.013511  0.073567
# 2022-06-01 -0.031974  0.047159
# 2022-07-01  0.076386 -0.122299
# 2022-08-01 -0.079478 -0.081462
# 2022-09-01  0.081402 -0.105871
# 2022-10-01 -0.054800  0.038303
# 2022-11-01 -0.023351 -0.036998
# 2022-12-01  0.056005 -0.098706
# 2023-01-01 -0.025333  0.021740
# 2023-02-01  0.023479 -0.016651
# 2023-03-01  0.014569 -0.047307
# 2023-04-01 -0.053596  0.080840
# 2023-05-01  0.080959 -0.104312
# 2023-06-01 -0.050330 -0.018755
# 2023-07-01  0.033720  0.079594
# 2023-08-01  0.027667  0.067598
# 2023-09-01  0.020040  0.094204
# 2023-10-01  0.033138 -0.043304

# %%
# Open a file in write mode
with open('WTI M MR Results.txt', 'w') as file:
    # Write the variables to the file
    file.write(f'{calculateMAE(y_test, predictions):.4f}\n')
    file.write(f'{calculateMAPE(y_test, predictions):.4f}\n')
    file.write(f'{calculateMSE(y_test, predictions):.4f}\n')
    file.write(f'{calculateRMSE(y_test, predictions):.4f}\n')
